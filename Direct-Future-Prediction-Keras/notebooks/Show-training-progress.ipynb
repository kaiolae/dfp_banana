# %%
import pandas as pd
training_dir = "../june13_goal_agnostic_3/"
training_data = training_dir+"/dfp_stats.txt"
data = pd.read_csv(training_data, sep=" ")

# %%
data.head
# Out:
# <bound method NDFrame.head of      GAME_NUMBER  Max_Score  mavg_score  mavg_loss  var_score  mavg_food  \
# 0             10          1        -0.7   0.016381       3.21        1.2
# 1             20          3         0.0   0.014882       3.60        1.5
# 2             30          3        -0.5   0.015075       4.25        1.8
# 3             40          3        -1.1   0.015293       1.49        1.2
# 4             50          3         0.4   0.015242       2.44        2.1
# 5             60          3         0.0   0.015308       3.20        2.2
# 6             70          5         1.4   0.015373       5.44        2.4
# 7             80          5        -0.8   0.015369       1.36        1.2
# 8             90          5         0.8   0.015284       2.36        2.8
# 9            100          5        -1.4   0.015412       3.24        1.4
# 10           110          5        -0.2   0.015395       2.36        1.7
# 11           120          5         0.6   0.015563       3.64        3.2
# 12           130          5         0.4   0.015582       6.84        3.1
# 13           140          5        -1.5   0.015750       3.05        1.7
# 14           150          7        -0.7   0.015891       9.61        2.3
# 15           160         11         0.3   0.015812      15.81        2.4
# 16           170         11        -0.9   0.015861       2.89        0.9
# 17           180         11         0.0   0.015863       4.80        1.5
# 18           190         11        -0.1   0.015860       1.89        1.7
# 19           200         11         0.4   0.015928       3.24        1.8
# 20           210         11         1.1   0.015929       3.49        2.1
# 21           220         11        -0.2   0.015787       3.56        1.7
# 22           230         11        -0.6   0.015807       1.64        0.5
# 23           240         11        -0.4   0.015865       1.64        1.8
# 24           250         11        -0.7   0.015800       2.01        1.2
# 25           260         11        -0.2   0.015684       3.56        0.9
# 26           270         11         0.2   0.015654       4.16        2.0
# 27           280         11        -0.1   0.015654       1.29        2.1
# 28           290         11        -0.6   0.015496       2.24        1.2
# 29           300         11        -0.7   0.015501       4.01        1.3
# ..           ...        ...         ...        ...        ...        ...
# 370         3710         29         2.8   0.021443      93.96        8.7
# 371         3720         29        -7.0   0.021287     160.60        5.0
# 372         3730         29        -2.3   0.021224     116.61        4.9
# 373         3740         29        -7.9   0.021076     215.49        5.6
# 374         3750         29        -4.4   0.020987     162.04        3.1
# 375         3760         29        -5.4   0.020877     190.24        6.4
# 376         3770         29        -2.3   0.021177     281.41        7.3
# 377         3780         29        -9.4   0.020958     116.04        2.1
# 378         3790         29        -4.3   0.020882     152.41        5.4
# 379         3800         29        -0.6   0.020676     183.44        5.9
# 380         3810         29        -0.3   0.020754     205.21        7.0
# 381         3820         29         0.0   0.020547     292.60        9.0
# 382         3830         29         0.2   0.020478     166.76        9.0
# 383         3840         29        -3.9   0.020365     264.89        9.2
# 384         3850         29        -5.3   0.020590     185.41        5.1
# 385         3860         29         0.3   0.020447     241.01        7.0
# 386         3870         29        -0.1   0.020378     250.09        9.6
# 387         3880         29        -0.2   0.020573     163.76        6.5
# 388         3890         29        -0.8   0.020510     127.56        8.5
# 389         3900         29        -0.4   0.020670     102.84        6.5
# 390         3910         29        -3.4   0.020812     127.04        9.5
# 391         3920         29        -8.2   0.021318     276.16        7.4
# 392         3930         29         0.3   0.021027      88.21        5.2
# 393         3940         29        -3.0   0.020980     245.40       10.0
# 394         3950         29         4.0   0.021075     114.40        9.2
# 395         3960         29        -4.5   0.021058     206.45        6.6
# 396         3970         29        -7.1   0.021473     204.89       10.7
# 397         3980         29         2.8   0.021587     131.76        7.8
# 398         3990         29        -3.4   0.021736     150.64        7.7
# 399         4000         29        -5.2   0.021651     190.96        5.4
#
#      mavg_poison  Unnamed: 7
# 0            1.9         NaN
# 1            1.5         NaN
# 2            2.3         NaN
# 3            2.3         NaN
# 4            1.7         NaN
# 5            2.2         NaN
# 6            1.0         NaN
# 7            2.0         NaN
# 8            2.0         NaN
# 9            2.8         NaN
# 10           1.9         NaN
# 11           2.6         NaN
# 12           2.7         NaN
# 13           3.2         NaN
# 14           3.0         NaN
# 15           2.1         NaN
# 16           1.8         NaN
# 17           1.5         NaN
# 18           1.8         NaN
# 19           1.4         NaN
# 20           1.0         NaN
# 21           1.9         NaN
# 22           1.1         NaN
# 23           2.2         NaN
# 24           1.9         NaN
# 25           1.1         NaN
# 26           1.8         NaN
# 27           2.2         NaN
# 28           1.8         NaN
# 29           2.0         NaN
# ..           ...         ...
# 370          5.9         NaN
# 371         12.0         NaN
# 372          7.2         NaN
# 373         13.5         NaN
# 374          7.5         NaN
# 375         11.8         NaN
# 376          9.6         NaN
# 377         11.5         NaN
# 378          9.7         NaN
# 379          6.5         NaN
# 380          7.3         NaN
# 381          9.0         NaN
# 382          8.8         NaN
# 383         13.1         NaN
# 384         10.4         NaN
# 385          6.7         NaN
# 386          9.7         NaN
# 387          6.7         NaN
# 388          9.3         NaN
# 389          6.9         NaN
# 390         12.9         NaN
# 391         15.6         NaN
# 392          4.9         NaN
# 393         13.0         NaN
# 394          5.2         NaN
# 395         11.1         NaN
# 396         17.8         NaN
# 397          5.0         NaN
# 398         11.1         NaN
# 399         10.6         NaN
#
# [400 rows x 8 columns]>

# %%
#Loss: not going anywhere! maybe due to the data changing as policy changes
data[['mavg_loss']].plot()

# %%
#That looks promising. Initially, food and poison increases.
#Later, only food keeps increasing.
data['median_avg_score']= data['mavg_score'].rolling(11).median()
data['median_foods']= data['mavg_food'].rolling(11).median()
data['median_poisons']= data['mavg_poison'].rolling(11).median()
data[['median_avg_score', 'median_foods', 'median_poisons']].plot()

# %%
#Result: After 2000 episodes, the result is definitely still improving!
#Try 4000 next
