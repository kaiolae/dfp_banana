# %%
import pandas as pd
training_dir = "../oct1_battery_balanced_agnostic_battery_limit_on/"
training_data = training_dir+"/dfp_stats.txt"
data = pd.read_csv(training_data, sep=" ")

# %%
data.head
# Out:
# <bound method NDFrame.head of     GAME_NUMBER  Max_Score  mavg_score  mavg_loss  var_score  mavg_battery  \
# 0            20          3         0.0   0.108268       2.00          14.2
# 1            30          5         0.8   0.103057       4.36          -0.8
# 2            40          5         0.5   0.102240       1.85          39.6
# 3            50          5        -0.2   0.112668       2.36          20.0
# 4            60          5         0.3   0.117237       1.21           9.2
# 5            70          5        -0.1   0.117459       0.89          29.4
# 6            80          5         0.1   0.121741       1.09          -0.8
# 7            90          5        -1.0   0.133201       5.80          69.8
# 8           100          5         0.1   0.132041       3.09          -0.8
# 9           110          5        -0.7   0.123711       4.01          19.6
# 10          120          5         1.1   0.129690       2.09          19.6
# 11          130          5        -1.1   0.138776       4.89           9.4
# 12          140          5        -0.6   0.125311       1.44          -0.6
# 13          150          5        -0.7   0.126761       2.61          -0.4
# 14          160          5         0.1   0.123593       2.69          39.4
# 15          170          5         0.8   0.130584       3.56          29.4
# 16          180          5         0.4   0.140083       2.64          39.6
# 17          190          5         0.3   0.133362       3.21          19.8
# 18          200          5        -0.2   0.134799       2.56          49.6
# 19          210          5         0.7   0.142168       0.61          19.2
# 20          220          5        -0.3   0.134844       1.41           9.4
#
#     mavg_food  mavg_poison  Unnamed: 8
# 0         1.2          1.2         NaN
# 1         1.9          1.1         NaN
# 2         1.5          1.0         NaN
# 3         0.7          0.9         NaN
# 4         1.1          0.8         NaN
# 5         0.9          1.0         NaN
# 6         0.9          0.8         NaN
# 7         1.1          2.1         NaN
# 8         1.1          1.0         NaN
# 9         1.0          1.7         NaN
# 10        2.3          1.2         NaN
# 11        0.8          1.9         NaN
# 12        1.1          1.7         NaN
# 13        0.9          1.6         NaN
# 14        1.7          1.6         NaN
# 15        2.0          1.2         NaN
# 16        1.4          1.0         NaN
# 17        1.9          1.6         NaN
# 18        1.8          2.0         NaN
# 19        1.3          0.6         NaN
# 20        0.8          1.1         NaN  >

# %%
#Loss: not going anywhere! maybe due to the data changing as policy changes
data[['mavg_loss']].plot()

# %%
#That looks promising. Initially, food and poison increases.
#Later, only food keeps increasing.
data['median_avg_score']= data['mavg_score'].rolling(11).median()
data['median_foods']= data['mavg_food'].rolling(11).median()
data['median_poisons']= data['mavg_poison'].rolling(11).median()
data['median_battery']= data['mavg_battery'].rolling(11).median()
data[['median_avg_score', 'median_foods', 'median_poisons']].plot()

# %%
data[['median_battery']].plot()
