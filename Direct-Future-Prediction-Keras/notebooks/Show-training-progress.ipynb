# %%
import pandas as pd
training_dir = "../june27_battery_sparse1_agnostic_battery_limit_on/"
training_data = training_dir+"/dfp_stats.txt"
data = pd.read_csv(training_data, sep=" ")

# %%
data.head
# Out:
# <bound method NDFrame.head of      GAME_NUMBER  Max_Score  mavg_score  mavg_loss  var_score  mavg_battery  \
# 0             10          1        -0.2   0.002408       0.96          -1.0
# 1             20          1        -0.5   0.002302       0.45          -0.8
# 2             30          2         0.0   0.002714       0.80          -1.0
# 3             40          2         0.6   0.002601       0.44          -1.0
# 4             50          2        -0.1   0.002604       0.69          -0.8
# 5             60          2        -0.1   0.002488       0.49          -1.0
# 6             70          2        -0.1   0.002626       1.29          -0.8
# 7             80          2         0.4   0.002787       1.24          -1.0
# 8             90          2         0.8   0.002862       1.36          -1.0
# 9            100          3         0.1   0.003006       1.69          -1.0
# 10           110          3        -0.5   0.002958       1.25          -1.0
# 11           120          3         0.3   0.003071       0.81          -1.0
# 12           130          3         0.8   0.003033       1.76          -0.8
# 13           140          3        -0.6   0.003051       0.64          -1.0
# 14           150          3         0.1   0.003077       2.29          -1.0
# 15           160          3        -0.2   0.003243       1.36          -0.6
# 16           170          5         0.1   0.003276       5.29          -1.0
# 17           180          5        -0.5   0.003384       1.65          -1.0
# 18           190          5         0.5   0.003255       1.45          -1.0
# 19           200          5         0.1   0.003378       2.49          -1.0
# 20           210          5        -0.3   0.003281       2.21          -0.8
# 21           220          5         0.5   0.003653       1.25          -1.0
# 22           230          5        -0.2   0.003541       0.76          -1.0
# 23           240          5        -0.4   0.003558       1.04          -1.0
# 24           250          5         0.5   0.003577       0.85          -0.8
# 25           260          5         0.0   0.003486       1.60           9.4
# 26           270          5         0.0   0.003602       1.40          -1.0
# 27           280          5         0.5   0.003623       2.05          -0.8
# 28           290          5        -0.2   0.003850       0.76          -1.0
# 29           300          5         0.3   0.003774       2.41          -1.0
# ..           ...        ...         ...        ...        ...           ...
# 779         7800         33         2.0   0.010706      75.20          49.6
# 780         7810         33         3.5   0.010507      62.25           9.2
# 781         7820         33         6.4   0.010693      73.04          59.4
# 782         7830         33         1.3   0.010578      53.61          39.6
# 783         7840         33         2.2   0.010604      85.56          39.4
# 784         7850         33         8.3   0.010771      77.81          39.6
# 785         7860         33         4.3   0.010905      45.81           9.6
# 786         7870         33         8.0   0.011026      94.80           9.6
# 787         7880         33         3.0   0.010894      46.80          19.4
# 788         7890         33         3.9   0.010909      94.69          19.6
# 789         7900         33         0.7   0.011108      12.81          -1.0
# 790         7910         33        -0.5   0.011034      29.45          -0.6
# 791         7920         33         5.4   0.011160     107.84          19.4
# 792         7930         33         5.9   0.011368      50.29          19.2
# 793         7940         33         3.5   0.011191      67.85          39.2
# 794         7950         33         4.4   0.011071     117.84          39.6
# 795         7960         33         5.6   0.011022      60.04          39.4
# 796         7970         33         1.3   0.011309       8.81          19.4
# 797         7980         33         8.3   0.011282     101.41         109.8
# 798         7990         33         7.4   0.011187      56.04          19.2
# 799         8000         33         1.6   0.011168      45.84          29.6
# 800         8010         33         3.8   0.011183      57.56          29.2
# 801         8020         33         3.1   0.011009      89.89          19.6
# 802         8030         33         2.7   0.011035      33.21           9.2
# 803         8040         33         3.8   0.010796      64.36          29.2
# 804         8050         33         6.5   0.011195      66.65          -1.0
# 805         8060         33         5.6   0.010880      71.84          59.4
# 806         8070         33         5.4   0.011189     155.84          79.8
# 807         8080         33         4.3   0.011164      60.41           9.4
# 808         8090         33         8.1   0.011259      53.69          19.2
#
#      mavg_food  mavg_poison  Unnamed: 8
# 0          0.4          0.6         NaN
# 1          0.6          1.1         NaN
# 2          0.7          0.7         NaN
# 3          0.7          0.1         NaN
# 4          0.4          0.5         NaN
# 5          0.6          0.7         NaN
# 6          1.2          1.3         NaN
# 7          1.1          0.7         NaN
# 8          1.4          0.6         NaN
# 9          1.0          0.9         NaN
# 10         0.4          0.9         NaN
# 11         1.1          0.8         NaN
# 12         1.4          0.6         NaN
# 13         0.6          1.2         NaN
# 14         1.1          1.0         NaN
# 15         1.2          1.4         NaN
# 16         1.0          0.9         NaN
# 17         0.7          1.2         NaN
# 18         1.2          0.7         NaN
# 19         1.1          1.0         NaN
# 20         0.8          1.1         NaN
# 21         1.6          1.1         NaN
# 22         0.9          1.1         NaN
# 23         0.8          1.2         NaN
# 24         1.2          0.7         NaN
# 25         1.1          1.1         NaN
# 26         0.7          0.7         NaN
# 27         2.0          1.5         NaN
# 28         0.6          0.8         NaN
# 29         1.3          1.0         NaN
# ..         ...          ...         ...
# 779        7.2          5.2         NaN
# 780        5.3          1.8         NaN
# 781        8.8          2.4         NaN
# 782        5.8          4.5         NaN
# 783        6.2          4.0         NaN
# 784       12.6          4.3         NaN
# 785        9.1          4.8         NaN
# 786       11.9          3.9         NaN
# 787        5.6          2.6         NaN
# 788        5.8          1.9         NaN
# 789        3.6          2.9         NaN
# 790        3.5          4.0         NaN
# 791        6.9          1.5         NaN
# 792        9.9          4.0         NaN
# 793        7.6          4.1         NaN
# 794        7.1          2.7         NaN
# 795        8.1          2.5         NaN
# 796        5.0          3.7         NaN
# 797       12.5          4.2         NaN
# 798        8.9          1.5         NaN
# 799        5.3          3.7         NaN
# 800        6.4          2.6         NaN
# 801        6.5          3.4         NaN
# 802        5.8          3.1         NaN
# 803        5.7          1.9         NaN
# 804        9.5          3.0         NaN
# 805        8.1          2.5         NaN
# 806       11.6          6.2         NaN
# 807        7.8          3.5         NaN
# 808        9.4          1.3         NaN
#
# [809 rows x 9 columns]>

# %%
#Loss: not going anywhere! maybe due to the data changing as policy changes
data[['mavg_loss']].plot()

# %%
#That looks promising. Initially, food and poison increases.
#Later, only food keeps increasing.
data['median_avg_score']= data['mavg_score'].rolling(11).median()
data['median_foods']= data['mavg_food'].rolling(11).median()
data['median_poisons']= data['mavg_poison'].rolling(11).median()
data['median_battery']= data['mavg_battery'].rolling(11).median()
data[['median_avg_score', 'median_foods', 'median_poisons']].plot()

# %%
data[['median_battery']].plot()
