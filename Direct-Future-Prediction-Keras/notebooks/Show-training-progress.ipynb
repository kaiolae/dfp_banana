# %%
import pandas as pd
training_dir = "../june17_testing_none_agnostic_more_3/"
training_data = training_dir+"/dfp_stats.txt"
data = pd.read_csv(training_data, sep=" ")

# %%
data.head
# Out:
# <bound method NDFrame.head of      GAME_NUMBER  Max_Score  mavg_score  mavg_loss  var_score  mavg_food  \
# 0             10          4        -0.1   0.016220       4.29        1.4
# 1             20          4         0.3   0.014804       1.61        1.6
# 2             30          4        -1.0   0.014766       1.80        1.0
# 3             40          4        -0.1   0.014734       2.29        1.6
# 4             50          4        -0.1   0.014923       4.89        1.6
# 5             60          4        -0.3   0.014875       2.61        1.4
# 6             70          4        -0.5   0.014990       2.85        1.6
# 7             80          4         0.3   0.015016       5.21        2.6
# 8             90          4        -0.5   0.015161       3.25        2.9
# 9            100          4        -0.5   0.015296       1.65        1.8
# 10           110          4         0.8   0.015298       5.96        2.7
# 11           120          4         0.8   0.015443       1.76        2.9
# 12           130          4         0.7   0.015529       3.01        2.4
# 13           140          4        -0.8   0.015536       1.56        2.2
# 14           150          4         0.2   0.015615       2.56        2.4
# 15           160          4         0.0   0.015630       4.60        2.2
# 16           170          4         0.3   0.015538       2.41        1.9
# 17           180          4        -0.1   0.015594       3.69        2.5
# 18           190          4        -0.5   0.015784       4.05        2.2
# 19           200          4        -0.8   0.015933       4.56        2.4
# 20           210          4        -0.3   0.016094       3.61        2.4
# 21           220          4         0.3   0.015989       1.81        2.1
# 22           230          5         0.1   0.016045       6.09        2.3
# 23           240          5         0.1   0.016261       4.09        3.0
# 24           250          5        -0.9   0.016275       4.29        2.1
# 25           260          6        -0.1   0.016327       6.69        1.8
# 26           270          6         0.4   0.016286       5.04        2.3
# 27           280          6        -0.3   0.016551       3.21        3.4
# 28           290          6        -0.1   0.016511       4.29        2.7
# 29           300          6        -0.2   0.016672       2.56        3.2
# ..           ...        ...         ...        ...        ...        ...
# 370         3710         18         7.7   0.021980       9.61       11.7
# 371         3720         18         8.3   0.022037      14.61       12.0
# 372         3730         18         5.1   0.021901      10.89        8.6
# 373         3740         18         6.3   0.022005      17.41       10.5
# 374         3750         18         8.0   0.022094      14.20       11.6
# 375         3760         18         6.8   0.021928       9.76       11.7
# 376         3770         18         6.1   0.022058      16.29       10.3
# 377         3780         18         3.5   0.022192      13.85        9.3
# 378         3790         18         5.5   0.022348      12.25        9.8
# 379         3800         18         5.8   0.022316       5.96        9.8
# 380         3810         18         6.1   0.021998      10.09        9.5
# 381         3820         18         9.2   0.022115      15.96       12.1
# 382         3830         18         7.3   0.022043      10.81       10.0
# 383         3840         18         6.7   0.022093       9.21       11.2
# 384         3850         18         9.1   0.022263      17.29       12.6
# 385         3860         18         6.8   0.022000      12.96       10.3
# 386         3870         18         7.9   0.021988      12.29       11.3
# 387         3880         18         5.8   0.022161       4.36       10.0
# 388         3890         18         6.1   0.021839      10.49       11.0
# 389         3900         18         9.1   0.022023      10.09       12.1
# 390         3910         18         7.8   0.022079      12.76       11.3
# 391         3920         18         6.5   0.022094      12.85       11.3
# 392         3930         18         6.8   0.021889       6.76       11.1
# 393         3940         18         8.0   0.021937       6.20       12.4
# 394         3950         18         8.1   0.021749       8.29       10.9
# 395         3960         18         6.1   0.021711      17.29       10.6
# 396         3970         18         8.4   0.021985      12.04       13.0
# 397         3980         18         7.2   0.022073      17.96       11.7
# 398         3990         18         7.7   0.022140      12.01       11.9
# 399         4000         18         5.5   0.022177      12.25        9.8
#
#      mavg_poison  Unnamed: 7
# 0            1.5         NaN
# 1            1.3         NaN
# 2            2.0         NaN
# 3            1.7         NaN
# 4            1.7         NaN
# 5            1.7         NaN
# 6            2.1         NaN
# 7            2.3         NaN
# 8            3.4         NaN
# 9            2.3         NaN
# 10           1.9         NaN
# 11           2.1         NaN
# 12           1.7         NaN
# 13           3.0         NaN
# 14           2.2         NaN
# 15           2.2         NaN
# 16           1.6         NaN
# 17           2.6         NaN
# 18           2.7         NaN
# 19           3.2         NaN
# 20           2.7         NaN
# 21           1.8         NaN
# 22           2.2         NaN
# 23           2.9         NaN
# 24           3.0         NaN
# 25           1.9         NaN
# 26           1.9         NaN
# 27           3.7         NaN
# 28           2.8         NaN
# 29           3.4         NaN
# ..           ...         ...
# 370          4.0         NaN
# 371          3.7         NaN
# 372          3.5         NaN
# 373          4.2         NaN
# 374          3.6         NaN
# 375          4.9         NaN
# 376          4.2         NaN
# 377          5.8         NaN
# 378          4.3         NaN
# 379          4.0         NaN
# 380          3.4         NaN
# 381          2.9         NaN
# 382          2.7         NaN
# 383          4.5         NaN
# 384          3.5         NaN
# 385          3.5         NaN
# 386          3.4         NaN
# 387          4.2         NaN
# 388          4.9         NaN
# 389          3.0         NaN
# 390          3.5         NaN
# 391          4.8         NaN
# 392          4.3         NaN
# 393          4.4         NaN
# 394          2.8         NaN
# 395          4.5         NaN
# 396          4.6         NaN
# 397          4.5         NaN
# 398          4.2         NaN
# 399          4.3         NaN
#
# [400 rows x 8 columns]>

# %%
#Loss: not going anywhere! maybe due to the data changing as policy changes
data[['mavg_loss']].plot()

# %%
#That looks promising. Initially, food and poison increases.
#Later, only food keeps increasing.
data['median_avg_score']= data['mavg_score'].rolling(11).median()
data['median_foods']= data['mavg_food'].rolling(11).median()
data['median_poisons']= data['mavg_poison'].rolling(11).median()
data[['median_avg_score', 'median_foods', 'median_poisons']].plot()

# %%
#Result: After 2000 episodes, the result is definitely still improving!
#Try 4000 next
