# %%
#Starting as a notebook, but I should probably move most core functionality here to a python script.

from keras import backend as K
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
K.set_session(sess)

# %%
#Setting up the Unity environment

from gym_unity.envs.unity_env import UnityEnv, ActionFlattener
env = UnityEnv("../../unity_envs/kais_banana2", worker_id=12, use_visual=True, flatten_branched=True)
print("Resetting env")
initial_observation = env.reset()

# %%
#Importing parent level files
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from dfp import DFPAgent
from networks import Networks

#Setting up the agent.
misc = 100 # [Health]
prev_misc = misc
action_size = env.action_space.n
print("Env has ", action_size, " actions.")
measurement_size = 3 # [misc,posion, food]
timesteps = [1,2,4,8,16,32]
goal_size = measurement_size * len(timesteps)
img_rows , img_cols = 84, 84
img_channels = 3
state_size = (img_rows, img_cols, img_channels)
agent = DFPAgent(state_size, measurement_size, action_size, timesteps)
agent.model = Networks.dfp_network(state_size, measurement_size, goal_size, action_size, len(timesteps), agent.learning_rate)
# Out:
# Env has  27  actions.

# %%
import numpy as np
s_t = initial_observation
s_t = np.expand_dims(s_t, axis=0) # 1x64x64x4
food=0
poison=0
m_t = np.array([misc/100.0, food, poison])
goal=np.array([0, 1.0, -1.0] * len(timesteps))
inference_goal=goal

# %%
#loading stored model
loaded_model = "../may24_fixed_visual_input_kais2_both_goal/model/dfp.h5"
agent.load_model(loaded_model)
agent.epsilon = agent.final_epsilon #To not start in explore-mode

done=False
num_timesteps=300

# %%
#Running model on environment, remembering the "strongest" predictions.
#TODO: Consider moving all this to separate script, storing states, predictions, actions, and load/analyze
#in a different notebook.
#Storing the frame, selected action and all predictions
recorded_frames = []
recorded_actions = []
recorded_predictions = [] #ALL predictions for the recorded frame.
recorded_prediction_weighted_sums = [] #Predictions multiplied by the weights, giving 1 number for each action.
for t in range(num_timesteps):

    predicted_effects  = agent.get_predicted_effects(s_t, m_t, goal) #3x6 (3 meas, 6 timesteps for each action.)
    obj = np.sum(np.multiply(predicted_effects, inference_goal), axis=1) # num_action
    #KOE: Double-check the NN output a bit.
    action_idx = np.argmax(obj)
    print("Most optimistic predictions is ", obj[action_idx])
    print("The related measurements: ", predicted_effects[action_idx])
    print("Action is ", convert_action_id_to_name(action_idx))
    observation, reward, done, info = env.step(action_idx)
    
    
    recorded_frames.append(observation)
    recorded_actions.append(action_idx)
    recorded_predictions.append(predicted_effects)
    recorded_prediction_weighted_sums.append(obj)
    #print("Full set of predictions: ", recorded_predictions)
    #print("weighted predictions per action: ", obj)
    
    meas = info['brain_info'].vector_observations
    if (done):
        print("Game done at timestep ", t)
        print ("Episode Finish ")
        misc = 100
        x_t1 = env.reset()
    else:
        x_t1 = observation
        misc = meas[0][0]
        
    s_t1 = x_t1
    s_t1 = np.expand_dims(x_t1, axis=0) # 1x64x64x4

    if (reward==-1): # Pick up Poison
        poison += 1
        print("Picked up. Current poison is ", poison)
    if (reward==1): # Pick up food
        food += 1
        print("Picked up. Current food is ", food)
    # Update the cache
    prev_misc = misc

    #KOETODO: Think about normalization.
    m_t = np.array([meas[0][0]/100.0, food, poison]) # Measurement after transition
    s_t = s_t1
#env.close()
# Out:
# Most optimistic predictions is  0.06538747623562813
# The related measurements:  [0.         0.         0.         0.         0.04804292 0.
#  0.         0.         0.10533348 0.         0.2107344  0.
#  0.         0.34222224 0.33193916 0.         0.75202197 0.8503614 ]
# Action is  backward, , ,
# Most optimistic predictions is  0.4840906895697117
# The related measurements:  [0.         0.         0.         0.         0.04716563 0.
#  0.         0.12482984 0.09421777 0.         0.24970703 0.
#  0.         0.43941167 0.36342672 0.         0.88787097 0.80724996]
# Action is  forward,left, ,
# Most optimistic predictions is  0.2186526544392109
# The related measurements:  [0.         0.         0.         0.         0.0400974  0.
#  0.         0.08907519 0.10163525 0.         0.20591941 0.
#  0.         0.34177592 0.33539927 0.         0.7376002  0.75878096]
# Action is  forward,left, ,
# Most optimistic predictions is  0.21164832636713982
# The related measurements:  [0.         0.         0.         0.         0.03198851 0.
#  0.         0.13606548 0.11209261 0.         0.19469163 0.
#  0.         0.34898642 0.34451768 0.         0.70358986 0.7470633 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.2892710380256176
# The related measurements:  [0.         0.         0.         0.         0.03457611 0.
#  0.         0.12798864 0.08975578 0.         0.21071175 0.
#  0.         0.34673408 0.3290329  0.         0.7137769  0.72572774]
# Action is  forward,left, ,
# Most optimistic predictions is  0.3909297026693821
# The related measurements:  [0.         0.         0.         0.         0.06036979 0.
#  0.         0.10128177 0.10047305 0.         0.19948772 0.
#  0.         0.42385975 0.37098706 0.         0.8299101  0.7525193 ]
# Action is  forward,left, ,
# Picked up. Current poison is  1
# Most optimistic predictions is  0.14880571141839027
# The related measurements:  [0.         0.         0.         0.         0.05056247 0.
#  0.         0.1052447  0.13943079 0.         0.20547262 0.
#  0.         0.39928648 0.45897308 0.         0.8071149  0.8204716 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.01395072415471077
# The related measurements:  [0.         0.         0.         0.         0.02848579 0.
#  0.         0.07088776 0.13383678 0.         0.14029081 0.
#  0.         0.31733692 0.3781445  0.         0.7196608  0.7507301 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.2414359338581562
# The related measurements:  [0.         0.         0.         0.         0.04695455 0.
#  0.         0.11384305 0.12803146 0.         0.19287585 0.
#  0.         0.41065994 0.40963727 0.         0.8248286  0.81005734]
# Action is  forward,left, ,
# Most optimistic predictions is  0.20115767791867256
# The related measurements:  [0.         0.         0.         0.         0.04871118 0.
#  0.         0.10963092 0.13400997 0.         0.18867597 0.
#  0.         0.37511492 0.43399358 0.         0.8085428  0.76151454]
# Action is  forward,left, ,
# Most optimistic predictions is  0.3172701932489872
# The related measurements:  [0.         0.         0.         0.         0.04899899 0.
#  0.         0.12823236 0.11994016 0.         0.18316635 0.
#  0.         0.3853659  0.41142854 0.         0.8481265  0.7452512 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.3477003239095211
# The related measurements:  [0.         0.         0.         0.         0.05235137 0.
#  0.         0.12956727 0.12102894 0.         0.1929018  0.
#  0.         0.3790829  0.3953501  0.         0.8313869  0.7212109 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.3985587954521179
# The related measurements:  [0.         0.         0.         0.         0.06574576 0.
#  0.         0.1367059  0.13175896 0.         0.21564214 0.
#  0.         0.44097784 0.46025497 0.         0.91274256 0.7812415 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0
]
# Action is  forward,left, ,
# Most optimistic predictions is  0.5187963880598545
# The related measurements:  [0.         0.         0.         0.         0.038589   0.
#  0.         0.14610282 0.08871238 0.         0.1849926  0.
#  0.         0.47458008 0.38492078 0.         1.1160564  0.9678914 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.6141206324100494
# The related measurements:  [0.         0.         0.         0.         0.06375229 0.
#  0.         0.16364865 0.11842061 0.         0.23495805 0.
#  0.         0.5394934  0.48354942 0.         1.2097436  0.99550533]
# Action is  forward,left, ,
# Most optimistic predictions is  0.24738311395049095
# The related measurements:  [0.         0.         0.         0.         0.05825775 0.
#  0.         0.         0.0794825  0.         0.21594553 0.
#  0.         0.4962587  0.43201268 0.         0.89201957 0.90360326]
# Action is  backward, , ,
# Most optimistic predictions is  0.4803030900657177
# The related measurements:  [0.         0.         0.         0.         0.0397932  0.
#  0.         0.13372299 0.08651427 0.         0.25991744 0.15369
#  0.         0.60287714 0.36891848 0.         0.93951756 0.8864025 ]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  0.6601852253079414
# The related measurements:  [0.         0.         0.         0.         0.06749592 0.
#  0.         0.1526672  0.07239689 0.         0.22215442 0.
#  0.         0.49977472 0.41418332 0.         1.0377319  0.8330587 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.7022308707237244
# The related measurements:  [0.         0.         0.         0.         0.07157232 0.
#  0.         0.1721916  0.08882177 0.         0.23935941 0.
#  0.         0.51728505 0.43027487 0.         1.0588965  0.8379774 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.5694363042712212
# The related measurements:  [0.         0.         0.         0.         0.07695814 0.
#  0.         0.16370359 0.12334181 0.         0.20381175 0.
#  0.         0.5388431  0.45801994 0.         1.0621297  0.89464825]
# Action is  forward,left, ,
# Most optimistic predictions is  0.5104185789823532
# The related measurements:  [0.         0.         0.         0.         0.06804286 0.
#  0.         0.12423703 0.12611091 0.         0.24139854 0.
#  0.         0.47276556 0.42591602 0.         0.9676761  0.8116746 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.5314603261649609
# The related measurements:  [0.         0.         0.         0.         0.04701095 0.
#  0.         0.16510354 0.13294742 0.         0.24654776 0.
#  0.         0.4833635  0.4226499  0.         0.93927646 0.7942446 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.436542060226202
# The related measurements:  [0.         0.         0.         0.         0.04783371 0.
#  0.         0.12391742 0.11694493 0.         0.24066216 0.
#  0.         0.46743923 0.44846672 0.         0.9228472  0.800746  ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.4734281711280346
# The related measurements:  [0.         0.         0.         0.         0.04302866 0.
#  0.         0.11636762 0.10945717 0.         0.23481339 0.
#  0.         0.4637572  0.42233247 0.         0.908423   0.76117206]
# Action is  forward,left, ,
# Most optimistic predictions is  0.42969199642539024
# The related measurements:  [0.         0.         0.         0.         0.05015378 0.
#  0.         0.12808813 0.1214856  0.         0.20714304 0.
#  0.         0.46052295 0.41277748 0.         0.8933367  0.77528954]
# Action is  forward,left, ,
# Most optimistic predictions is  0.503242488950491
# The related measurements:  [0.         0.         0.         0.         0.05500456 0.
#  0.         0.11697823 0.09653147 0.         0.21196158 0.
#  0.         0.4766966  0.395196   0.         0.88308007 0.7487511 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.5401071570813656
# The related measurements:  [0.         0.         0.         0.         0.04464089 0.
#  0.         0.14010306 0.1310832  0.         0.22128555 0.
#  0.         0.5105423  0.41359383 0.         1.0217332  0.85352075]
# Action is  forward,left, ,
# Most optimistic predictions is  0.5547652430832386
# The related measurements:  [0.         0.         0.         0.         0.03375925 0.
#  0.         0.10538001 0.09383113 0.         0.26814955 0.
#  0.         0.41973704 0.33759272 0.         0.9155464  0.7563832 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.21515656355768442
# The related measurements:  [0.         0.         0.         0.         0.00525546 0.
#  0.         0.08229857 0.04951678 0.         0.1798957  0.
#  0.         0.29409558 0.28050607 0.         0.57942885 0.59579474]
# Action is  forward,left, ,
# Most optimistic predictions is  0.2627562992274761
# The related measurements:  [0.         0.         0.         0.         0.02699305 0.
#  0.         0.09507772 0.08668491 0.         0.14179794 0.17682977
#  0.         0.32679102 0.28458983 0.         0.79048216 0.5702811 ]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  0.36154112219810486
# The related measurements:  [0.         0.         0.         0.         0.07592348 0.
#  0.         0.10707702 0.12892345 0.         0.1926131  0.
#  0.         0.47328773 0.41571027 0.         0.86983496 0.81256145]
# Action is  forward,left, ,
# Most optimistic predictions is  0.4354240968823433
# The related measurements:  [0.         0.         0.         0.         0.06288356 0.
#  0.         0.12087777 0.11293119 0.         0.21875864 0.
#  0.         0.4453617  0.41828477 0.         0.8644268  0.7456684 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.35554639250040054
# The related measurements:  [0.         0.         0.         0.         0.06567372 0.
#  0.         0.11259496 0.13248493 0.         0.22868542 0.
#  0.         0.4534907  0.4010509  0.         0.787456   0.75881857]
# Action is  forward,left, ,
# Most optimistic predictions is  0.38711443543434143
# The related measurements:  [0.         0.         0.         0.         0.06375573 0.
#  0.         0.11331141 0.11103354 0.         0.22317353 0.
#  0.         0.4620042  0.4202164  0.         0.89275223 0.8366327 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.2649933062493801
# The related measurements:  [0.         0.         0.         0.         0.05205407 0.
#  0.         0.11778113 0.12641157 0.         0.1909508  0.
#  0.         0.40819532 0.4250907  0.         0.8261433  0.77862906]
# Action is  forward,left, ,
# Most optimistic predictions is  0.2547501400113106
# The related measurements:  [0.         0.         0.         0.         0.06484632 0.
#  0.         0.11035036 0.12762944 0.         0.20784698 0.
#  0.         0.4178132  0.4201128  0.         0.7665991  0.7649636 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.3466031923890114
# The related measurements:  [0.         0.         0.         0.         0.06629742 0.
#  0.         0.13178906 0.13301939 0.         0.20447138 0.
#  0.         0.40933788 0.38862965 0.         0.8051774  0.7488209 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.4081733673810959
# The related measurements:  [0.         0.         0.         0.         0.06481836 0.
#  0.         0.12420641 0.12034532 0.         0.21442313 0.
#  0.         0.4238889  0.37886542 0.         0.7844731  0.7044258 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.4353572130203247
# The related measurements:  [0.         0.         0.         0.         0.07350034 0.
#  0.         0.12902187 0.11295357 0.         0.20153633 0.
#  0.         0.44640985 0.4058443  0.         0.8745808  0.7708941 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.3543485626578331
# The related measurements:  [0.         0.         0.         0.         0.07793822 0.
#  0.         0.08708453 0.09596774 0.         0.25165087 0.
#  0.         0.43878987 0.41843522 0.         0.9310078  0.9177198 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.48976584523916245
# The related measurements:  [0.         0.         0.         0.         0.07722247 0.
#  0.         0.13040917 0.13439527 0.         0.21875018 0.
#  0.         0.46514112 0.40802705 0.         0.9089299  0.76826465]
# Action is  forward,left, ,
# Most optimistic predictions is  0.395491324365139
# The related measurements:  [0.         0.         0.         0.         0.06595219 0.
#  0.         0.12208256 0.12561046 0.         0.21041211 0.
#  0.         0.41735977 0.37867916 0.         0.8120532  0.7280789 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0
]
# Action is  forward,left, ,
# Most optimistic predictions is  0.21400907263159752
# The related measurements:  [0.         0.         0.         0.         0.05435467 0.
#  0.         0.08591256 0.10030391 0.         0.16858208 0.16745998
#  0.         0.31149414 0.28075117 0.         0.76726544 0.62508476]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  0.18596744164824486
# The related measurements:  [0.         0.         0.         0.         0.02165334 0.
#  0.         0.07774042 0.08986775 0.         0.17307305 0.
#  0.         0.33100855 0.3349678  0.         0.6653198  0.6579922 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.185829009860754
# The related measurements:  [0.         0.         0.         0.         0.03826966 0.
#  0.         0.05015218 0.07154251 0.         0.14398104 0.1643974
#  0.         0.2630948  0.25478354 0.         0.7291868  0.548132  ]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  0.2693653181195259
# The related measurements:  [0.         0.         0.         0.         0.06412441 0.
#  0.         0.11474942 0.11185544 0.         0.20494853 0.
#  0.         0.39736882 0.35796642 0.         0.70880854 0.75081253]
# Action is  forward,left, ,
# Most optimistic predictions is  0.2382873073220253
# The related measurements:  [0.         0.         0.         0.         0.06375837 0.
#  0.         0.11866903 0.10997909 0.         0.2040171  0.
#  0.         0.38251773 0.38165742 0.         0.69758123 0.73661965]
# Action is  forward,left, ,
# Most optimistic predictions is  0.13681726157665253
# The related measurements:  [0.         0.         0.         0.         0.07088032 0.
#  0.         0.09172607 0.13398427 0.         0.21812998 0.
#  0.         0.40277934 0.41861454 0.         0.7506147  0.84471434]
# Action is  forward,left, ,
# Most optimistic predictions is  0.05165813863277435
# The related measurements:  [0.         0.         0.         0.         0.07221541 0.
#  0.         0.09295094 0.13662446 0.         0.21037151 0.
#  0.         0.3992218  0.44925717 0.         0.71878636 0.85600626]
# Action is  forward,left, ,
# Most optimistic predictions is  0.013022508472204208
# The related measurements:  [0.         0.         0.         0.         0.06036436 0.
#  0.         0.09500964 0.12829158 0.         0.20765747 0.
#  0.         0.37813517 0.43629134 0.         0.6685057  0.83206695]
# Action is  forward,left, ,
# Most optimistic predictions is  0.02082555741071701
# The related measurements:  [0.         0.         0.         0.         0.07663286 0.
#  0.         0.11031646 0.14581408 0.         0.22724581 0.
#  0.         0.41663492 0.48620355 0.         0.72485083 0.9028377 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.05464566498994827
# The related measurements:  [0.         0.         0.         0.         0.06617568 0.
#  0.         0.11336213 0.14638449 0.         0.22938354 0.
#  0.         0.4178453  0.47902903 0.         0.7254827  0.8721902 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.04361219331622124
# The related measurements:  [0.         0.         0.         0.         0.05210219 0.
#  0.         0.10235499 0.14209387 0.         0.2112407  0.
#  0.         0.39319414 0.45903996 0.         0.733524   0.84767   ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.04652867093682289
# The related measurements:  [0.         0.         0.         0.         0.03921272 0.
#  0.         0.09102373 0.14433166 0.         0.18148342 0.
#  0.         0.38918707 0.41659045 0.         0.70634085 0.799797  ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.12985779717564583
# The related measurements:  [0.         0.         0.         0.         0.0359232  0.
#  0.         0.1018112  0.12861648 0.         0.18684667 0.
#  0.         0.39580643 0.40706527 0.         0.7074806  0.76232857]
# Action is  forward,left, ,
# Most optimistic predictions is  0.075742918998003
# The related measurements:  [0.         0.         0.         0.         0.04920294 0.
#  0.         0.08604927 0.14010909 0.         0.20394592 0.
#  0.         0.40889135 0.4158966  0.         0.7021882  0.81852907]
# Action is  forward,left, ,
# Most optimistic predictions is  0.030322719365358353
# The related measurements:  [0.         0.         0.         0.         0.02380371 0.
#  0.         0.09014872 0.12006762 0.         0.16844773 0.
#  0.         0.33837783 0.3706418  0.         0.6366232  0.7363691 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.06583927944302559
# The related measurements:  [0.         0.         0.         0.         0.02091322 0.
#  0.         0.08126008 0.08557238 0.         0.14381039 0.
#  0.         0.29373837 0.31685597 0.         0.45448643 0.6576194 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.008761081844568253
# The related measurements:  [0.         0.         0.         0.         0.05426607 0.
#  0.         0.04909986 0.11377253 0.         0.14105374 0.12629108
#  0.         0.32197663 0.3675783  0.         0.750893   0.71840847]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  0.05199670419096947
# The related measurements:  [0.         0.         0.         0.         0.02067595 0.
#  0.         0.07272335 0.05760275 0.         0.15572041 0.
#  0.         0.2572079  0.26351374 0.         0.5346676  0.667882  ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.11430778726935387
# The related measurements:  [0.         0.         0.         0.         0.04864869 0.
#  0.         0.02225821 0.06620684 0.         0.17070492 0.14179905
#  0.         0.296064   0.2732662  0.         0.79239345 0.7344894 ]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  0.21404189988970757
# The related measurements:  [0.         0.         0.         0.         0.05700237 0.
#  0.         0.15208721 0.10342924 0.         0.21205555 0.
#  0.         0.3953036  0.4001419  0.         0.81132776 0.91016346]
# Action is  forward,left, ,
# Most optimistic predictions is  0.13075516000390053
# The related measurements:  [0.         0.         0.         0.         0.04247842 0.
#  0.         0.0799816  0.09096485 0.         0.21296784 0.
#  0.         0.40281266 0.38720566 0.         0.74104726 0.8703621 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.2159581147134304
# The related measurements:  [0.         0.         0.         0.         0.05055616 0.
#  0.         0.10226201 0.07081715 0.         0.20037325 0.
#  0.         0.40144426 0.34005684 0.         0.6962323  0.8240359 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.2869170047342777
# The related measurements:  [0.         0.         0.         0.         0.05460439 0.
#  0.         0.13016275 0.07930545 0.         0.2239931  0.
#  0.         0.4304227  0.35868025 0.         0.77901036 0.8932906 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.3910714462399483
# The related measurements:  [0.         0.         0.         0.         0.05028727 0.
#  0.         0.10265968 0.05932098 0.         0.20657724 0.
#  0.         0.39864647 0.30943495 0.         0.8109594  0.8093027 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.3846619315445423
# The related measurements:  [0.         0.         0.         0.         0.04990038 0.
#  0.         0.10198046 0.05920839 0.         0.20543686 0.
#  0.         0.39620388 0.3088603  0.         0.80686253 0.8076535 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.37825387716293335
# The related measurements:  [0.         0.         0.         0.         0.04950769 0.
#  0.         0.1013019  0.05908899 0.         0.20429935 0.
#  0.         0.39375725 0.30829036 0.         0.8027573  0.8059903 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.282483771443367
# The related measurements:  [0.         0.         0.         0.         0.03917162 0.
#  0.         0.09096991 0.05108715 0.         0.18725154 0.
#  0.         0.3661823  0.30472338 0.         0.7541846  0.79946566]
# Action is  forward,left, ,
# Most optimistic predictions is  0.25423822924494743
# The related measurements:  [0.         0.         0.         0.         0.04973431 0.
#  0.         0.12560555 0.07083636 0.         0.21784212 0.
#  0.         0.37728062 0.33689845 0.         0.75038254 0.8588721 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.3251540996134281
# The related measurements:  [0.         0.         0.         0.         0.04656387 0.
#  0.         0.09889118 0.0655546  0.         0.19580893 0.
#  0.         0.37029934 0.30414692 0.         0.78238493 0.79909265]
# Action is  forward,left, ,
# Most optimistic predictions is  0.18288172036409378
# The related measurements:  [0.         0.         0.         0.         0.08797073 0.
#  0.         0.11320952 0.10094975 0.         0.23072267 0.
#  0.         0.44322032 0.36173752 0.         0.69993705 0.9294913 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.3557448498904705
# The related measurements:  [0.         0.         0.         0.         0.05285919 0.
#  0.         0.09884365 0.05537429 0.         0.21080033 0.
#  0.         0.38534555 0.31704634 0.         0.8056393  0.82532257]
# Action is  forward,left, ,
# Most optimistic predictions is  0.26532647386193275
# The related measurements:  [0.         0.         0.         0.         0.0424496  0.
#  0.         0.07263717 0.04513486 0.         0.17705809 0.
#  0.         0.34642732 0.29327926 0.         0.7486832  0.7835148 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.23142488300800323
# The related measurements:  [0.         0.         0.         0.         0.0415976  0.
#  0.         0.09050639 0.04968598 0.         0.1671746  0.14493589
#  0.         0.32739988 0.25916198 0.         0.7852075  0.72667724]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  -0.11986048892140388
# The related measurements:  [0.         0.         0.         0.         0.04903206 0.
#  0.         0.         0.09244418 0.         0.15073575 0.
#  0.         0.3353016  0.42263678 0.         0.79340106 0.93325   ]
# Action is  backward, , ,
# Most optimistic predictions is  -0.14038008078932762
# The related measurements:  [0.         0.         0.         0.         0.03653711 0.
#  0.         0.         0.03175455 0.         0.05996417 0.
#  0.         0.21097608 0.3133992  0.         0.72756666 0.83027035]
# Action is  backward, , ,
# Most optimistic predictions is  -0.17572184652090073
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.00985415 0.         0.         0.04850957 0.08171149
#  0.         0.1549728  0.25802165 0.         0.6466685  0.6959937 ]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  -0.019343954510986805
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.         0.02344852 0.         0.         0.0761208
#  0.         0.00470158 0.11633025 0.         0.5536134  0.3617594 ]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  -0.16796369035728276
# The related measurements:  [0.         0.         0.         0.         0.00078174 0.
#  0.         0.         0.03358073 0.         0.0375325  0.10086603
#  0.         0.09853663 0.19138911 0.         0.569394   0.5483727 ]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  -0.1442873515188694
# The related measurements:  [0.         0.         0.         0.         0.03069617 0.
#  0.         0.08881941 0.0961218  0.         0.11664053 0.
#  0.         0.3244188  0.39042887 0.         0.77064914 0.98896074]
# Action is  forward,left, ,
# Picked up. Current poison is  2
# Most optimistic predictions is  0.03462090343236923
# The related measurements:  [0.         0.         0.         0.         0.07592743 0.
#  0.         0.12923262 0.13110732 0.         0.19131924 0.
#  0.         0.4226574  0.52239853 0.         0.9458964  1.0769063 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.00045489147305488586
# The related measurements:  [0.         0.         0.         0.         0.06068372 0.
#  0.         0.         0.08713099 0.         0.1888108  0.
#  0.         0.37994826 0.43045586 0.         0.80677855 0.9181796 ]
# Action is  backward, , ,
# Most optimistic predictions is  0.2054377906024456
# The related measurements:  [0.         0.         0.         0.         0.04871855 0.
#  0.         0.         0.07125742 0.         0.20781367 0.
#  0.         0.44509536 0.3530895  0.         0.8036525  0.8754954 ]
]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  -0.008170180022716522
# The related measurements:  [0.         0.         0.         0.         0.03015223 0.
#  0.         0.04663271 0.04338681 0.         0.13996401 0.13975708
#  0.         0.21463366 0.27951148 0.         0.6901524  0.6670498 ]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  0.15066442266106606
# The related measurements:  [0.         0.         0.         0.         0.04240914 0.
#  0.         0.10114175 0.03192373 0.         0.1555132  0.
#  0.         0.2755037  0.25826663 0.         0.59332955 0.72704256]
# Action is  forward,left, ,
# Most optimistic predictions is  0.19942288473248482
# The related measurements:  [0.         0.         0.         0.         0.05471551 0.
#  0.         0.10507732 0.03391801 0.         0.17169349 0.
#  0.         0.30369353 0.2902457  0.         0.638533   0.75012624]
# Action is  forward,left, ,
# Most optimistic predictions is  0.19122949242591858
# The related measurements:  [0.         0.         0.         0.         0.05439777 0.
#  0.         0.10489067 0.03481471 0.         0.17020467 0.
#  0.         0.30163676 0.29034188 0.         0.6366757  0.7514195 ]
# Action is  forward,left, ,
# Most optimistic predictions is  0.18383865803480148
# The related measurements:  [0.         0.         0.         0.         0.05383313 0.
#  0.         0.10414732 0.03466455 0.         0.16888995 0.
#  0.         0.29876074 0.28960243 0.         0.6320805  0.749606  ]
# Action is  forward,left, ,
# ...
#  0.         0.05572293 0.09239656 0.         0.07328016 0.
#  0.         0.09819267 0.30592307 0.         0.29562768 0.6549239 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.5204562805593014
# The related measurements:  [0.         0.         0.         0.         0.03514596 0.
#  0.         0.08664727 0.15099144 0.         0.06815096 0.
#  0.         0.11517423 0.37469208 0.         0.3395177  0.6394089 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.6509590349160135
# The related measurements:  [0.         0.         0.         0.         0.0049588  0.
#  0.         0.00110058 0.07222356 0.         0.02799488 0.08251481
#  0.         0.         0.28433698 0.         0.33272594 0.5786639 ]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  -0.3471662988886237
# The related measurements:  [0.         0.         0.         0.         0.01384251 0.
#  0.         0.06521802 0.05170925 0.         0.05977638 0.05874478
#  0.         0.09440856 0.27887818 0.         0.41973394 0.6108135 ]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  -0.2697628289461136
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.         0.03367444 0.         0.07200649 0.
#  0.         0.142567   0.28112438 0.         0.4944569  0.6639944 ]
# Action is  backward, , ,
# Most optimistic predictions is  -0.27333488315343857
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.         0.03337836 0.         0.07063826 0.
#  0.         0.13998969 0.28028762 0.         0.49158114 0.661878  ]
# Action is  backward, , ,
# Most optimistic predictions is  -0.36850491911172867
# The related measurements:  [0.         0.         0.         0.         0.0219175  0.
#  0.         0.06079173 0.03880022 0.         0.08377177 0.10456631
#  0.         0.11257612 0.33181247 0.         0.49755666 0.6699397 ]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  -0.3436316251754761
# The related measurements:  [0.         0.         0.         0.         0.03101658 0.
#  0.         0.09020937 0.05491164 0.         0.09958328 0.
#  0.         0.14459075 0.35115135 0.         0.43132335 0.734292  ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.37971076741814613
# The related measurements:  [0.         0.         0.         0.         0.02901907 0.
#  0.         0.06490337 0.07773133 0.         0.07630917 0.
#  0.         0.14702843 0.3318149  0.         0.41687652 0.7043011 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.37061062827706337
# The related measurements:  [0.         0.         0.         0.         0.0350577  0.
#  0.         0.07383764 0.09856025 0.         0.10462324 0.
#  0.         0.17934583 0.36139962 0.         0.44081178 0.74432695]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.538213636726141
# The related measurements:  [0.         0.         0.         0.         0.02093888 0.
#  0.         0.06264914 0.12558037 0.         0.07983664 0.
#  0.         0.12785058 0.3611353  0.         0.37902468 0.7217979 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.5066100545227528
# The related measurements:  [0.         0.         0.         0.         0.02534302 0.
#  0.         0.06876957 0.09314279 0.         0.08560527 0.
#  0.         0.11003041 0.34692502 0.         0.30205846 0.658349  ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.49154379521496594
# The related measurements:  [0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 3.0671014e-05
#  0.0000000e+00 0.0000000e+00 4.1681845e-02 5.5898953e-02 0.0000000e+00
#  8.1764035e-02 0.0000000e+00 0.0000000e+00 1.0561424e-01 2.8619295e-01
#  0.0000000e+00 1.8913524e-01 5.6767792e-01]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.3005738735664636
# The related measurements:  [0.         0.         0.         0.         0.00332061 0.
#  0.         0.08132581 0.07767363 0.         0.11819162 0.
#  0.         0.16928779 0.34196305 0.         0.40360093 0.65666395]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.43357281759381294
# The related measurements:  [0.         0.         0.         0.         0.02350735 0.
#  0.         0.08880195 0.12154901 0.         0.08662473 0.
#  0.         0.11264937 0.34373224 0.         0.33572298 0.61559796]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.4587254486978054
# The related measurements:  [0.         0.         0.         0.         0.01917352 0.
#  0.         0.07689604 0.10105109 0.         0.11015397 0.
#  0.         0.09765031 0.3419089  0.         0.26961693 0.5892562 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.5767456442117691
# The related measurements:  [0.         0.         0.         0.         0.01755716 0.
#  0.         0.07187958 0.09595719 0.         0.0665094  0.
#  0.         0.03750398 0.31533518 0.         0.2059129  0.5648163 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.5787426345050335
# The related measurements:  [0.         0.         0.         0.         0.02590481 0.
#  0.         0.06945331 0.12576431 0.         0.10716683 0.
#  0.         0.09571425 0.3667375  0.         0.21912353 0.60360354]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.5679724207147956
# The related measurements:  [0.         0.         0.         0.         0.01533592 0.
#  0.         0.07506958 0.0949702  0.         0.08892693 0.
#  0.         0.05254271 0.33041814 0.         0.17221318 0.5466724 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.6585320420563221
# The related measurements:  [0.         0.         0.         0.         0.02105384 0.
#  0.         0.04178726 0.09809533 0.         0.07822021 0.
#  0.         0.05296545 0.32772294 0.         0.14188938 0.5686299 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.7556627281010151
# The related measurements:  [0.         0.         0.         0.         0.02587203 0.
#  0.         0.1113157  0.08992603 0.         0.0498975  0.
#  0.         0.05070064 0.3292076  0.         0.         0.57431495]
# Action is  backward,left,rot_right,
# Most optimistic predictions is  -0.7569076409563422
# The related measurements:  [0.         0.         0.         0.         0.00527347 0.
#  0.         0.03162073 0.07802173 0.         0.03881708 0.
#  0.         0.02180057 0.3041631  0.         0.08001579 0.55225044]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.7368789128959179
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.06572118 0.0552188  0.         0.03431221 0.
#  0.         0.0195203  0.27801675 0.         0.         0.52319705]
# Action is  backward,left,rot_right,
# Most optimistic predictions is  -0.6975811682641506
# The related measurements:  [0.         0.         0.01790098 0.         0.         0.
#  0.         0.04244262 0.06529187 0.         0.         0.
#  0.         0.         0.24015552 0.         0.         0.41667542]
# Action is  backward,left,rot_right,
# Most optimistic predictions is  -0.528289720416069
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.         0.06366014 0.         0.         0.05528076
#  0.         0.         0.21529166 0.         0.24445082 0.43850797]
# Action is  backward, ,rot_right,
# Most optimistic predictions is  -0.6038737297058105
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.         0.07167428 0.         0.         0.08317471
#  0.         0.         0.26709372 0.         0.2913165  0.47324753]
# Action is  backward, ,rot_right,
# Most optimistic predictions is  -0.4663286618888378
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.         0.05920718 0.         0.         0.1397019
#  0.         0.         0.24608085 0.         0.35076228 0.372101  ]
# Action is  backward, ,rot_right,
# Most optimistic predictions is  -0.7548073716461658
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.         0.07150842 0.         0.03737646 0.08756227
#  0.         0.07086297 0.35652262 0.         0.23332916 0.58078265]
# Action is  backward, ,rot_right,
# Most optimistic predictions is  -0.6103256945498288
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.00330642 0.06611754 0.         0.         0.07952216
#  0.         0.         0.18519379 0.         0.14214212 0.42494074]
# Action is  backward, ,rot_left,
# Most optimistic predictions is  -0.8233436867594719
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.         0.07938015 0.         0.         0.06864105
#  0.         0.         0.33906204 0.         0.24971406 0.5859745 ]
# Action is  backward, ,rot_right,
# Most optimistic predictions is  -0.5904542990028858
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.         0.05430892 0.         0.         0.07699727
#  0.         0.         0.22697462 0.         0.17916845 0.41134194]
# Action is  backward, ,rot_right,
# Most optimistic predictions is  -0.6321286261081696
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.03651953 0.05856076 0.         0.07559539 0.
#  0.         0.10206463 0.35326582 0.         0.25179687 0.68627846]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.6151518858969212
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.04705651 0.06177028 0.         0.08951164 0.
#  0.         0.11488154 0.36228436 0.         0.27533785 0.7178848 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.6312073580920696
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.04310041 0.05793221 0.         0.06936722 0.
#  0.         0.08485314 0.33540672 0.         0.22302227 0.65821147]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.6991853341460228
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.03125705 0.08563266 0.         0.04879715 0.
#  0.         0.09910207 0.35657597 0.         0.21329676 0.64942974]
# Action is  forward,left, ,
# Picked up. Current food is  1
# Most optimistic predictions is  -0.32531132083386183
# The related measurements:  [0.         0.         0.         0.         0.01108903 0.
#  0.         0.08073435 0.12010935 0.         0.10019292 0.
#  0.         0.1982453  0.3571195  0.         0.3649007  0.6032448 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.18491780385375023
# The related measurements:  [0.         0.         0.         0.         0.0185431  0.
#  0.         0.08868681 0.11868578 0.         0.11968847 0.
#  0.         0.20832136 0.34176773 0.         0.38643944 0.5461435 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.1423844425007701
# The related measurements:  [0.         0.         0.         0.         0.01309205 0.
#  0.         0.09097919 0.11388176 0.         0.12197408 0.
#  0.         0.20298262 0.32471126 0.         0.36969918 0.50251853]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.13913482055068016
# The related measurements:  [0.         0.         0.         0.         0.02220844 0.
#  0.         0.08766659 0.09183468 0.         0.12072548 0.
#  0.         0.19091351 0.3197055  0.         0.38488582 0.5339945 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.24738452583551407
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.0761973  0.07262816 0.         0.10798929 0.
#  0.         0.13330068 0.28541446 0.         0.24300201 0.4498312 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.4552704067900777
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.01129395 0.0836999  0.         0.03658647 0.
#  0.         0.07618212 0.23576045 0.         0.15586464 0.41573724]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.3644075505435467
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.05973873 0.09952488 0.         0.09386031 0.
#  0.         0.11897018 0.23893286 0.         0.20524906 0.5037681 ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.5865467377007008
# The related measurements:  [0.         0.         0.         0.         0.03240236 0.
#  0.         0.06512605 0.13237016 0.         0.06813777 0.
#  0.         0.12969065 0.3574122  0.         0.09476672 0.48688793]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.5303471386432648
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.01981754 0.08793412 0.         0.05339056 0.
#  0.         0.09995901 0.26374847 0.         0.11047791 0.46230957]
# Action is  forward,left, ,
# Picked up. Current food is  2
# Most optimistic predictions is  -0.326360470848158
# The related measurements:  [0.         0.         0.         0.         0.0034721  0.
#  0.         0.05638608 0.11955266 0.         0.06290013 0.
#  0.         0.14333655 0.27965644 0.         0.21414141 0.40738764]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.5208641840144992
# The related measurements:  [0.         0.         0.         0.         0.00610324 0.
#  0.         0.03379438 0.10339066 0.         0.         0.
#  0.         0.04398458 0.25038487 0.         0.10345437 0.35442522]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.5809653615579009
# The related measurements:  [0.         0.         0.         0.         0.00764044 0.
#  0.         0.05038186 0.10100035 0.         0.06303702 0.
#  0.         0.10152446 0.3452689  0.         0.10943584 0.46671572]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.6982135912403464
# The related measurements:  [0.         0.         0.         0.         0.01141435 0.
#  0.         0.05502805 0.09378143 0.         0.03174002 0.
#  0.         0.04661212 0.32976973 0.         0.07325588 0.49271286]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.7523971553891897
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.         0.09537555 0.         0.02130255 0.08090693
#  0.         0.02306675 0.34096432 0.         0.2102034  0.48972306]
# Action is  backward, ,rot_right,
# Most optimistic predictions is  -0.13960432261228561
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.06963824 0.08498923 0.         0.09395755 0.
#  0.         0.15954724 0.25009248 0.         0.25891936 0.386585  ]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.3673992194235325
# The related measurements:  [0.         0.         0.         0.         0.02472103 0.
#  0.         0.07309629 0.11492254 0.         0.09678382 0.
#  0.         0.15238026 0.31685594 0.         0.20631512 0.48891726]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.34637515619397163
# The related measurements:  [0.         0.         0.         0.         0.03271667 0.
#  0.         0.05960276 0.10611358 0.         0.05476366 0.
#  0.         0.07648683 0.26959473 0.         0.1570227  0.35125947]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.3736500460654497
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.05115233 0.09537078 0.         0.03098617 0.
#  0.         0.04831131 0.21567301 0.         0.07646559 0.26952165]
# Action is  forward,left, ,
# Most optimistic predictions is  -0.4600381087511778
# The related measurements:  [0.         0.         0.         0.         0.         0.
#  0.         0.         0.11409143 0.         0.02309151 0.06944993
#  0.         0.04970235 0.23441167 0.         0.18520527 0.3000842 ]
# Action is  backward, ,rot_right,
# Game done at timestep  299
# Episode Finish

# %%
action_names = [[" ", "forward", "backward"], [" ", "right", "left"], [" ", "rot_left", "rot_right"], ["dont charge", "charge"]]
#OK! These seem right.
    
flattened_names = ActionFlattener([3,3,3,2])

# %%
#%%
def convert_action_id_to_name(id):
    un_flattened_indices = flattened_names.lookup_action(id)
    name = ""
    action_counter=0
    for i in un_flattened_indices:
        name+=action_names[action_counter][i]
        action_counter+=1
        name+=","
    return name
#%%

# %%
import matplotlib.pyplot as plt
for frame in range(20):#len(recorded_frames)):
    #plt.figure()
    #plt.imshow(np.array(recorded_frames[frame]))
    print("Suggesting action: ", convert_action_id_to_name(recorded_actions[frame]))
    print("id: ", recorded_actions[frame])
